# %% [markdown]
# # Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df = pd.read_csv("Desktop/home_prices2 - sheet.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area',fontsize="20",color="red")
plt.ylabel('Price',fontsize="20",color="red")
plt.scatter(df.area,df.price,color='red',marker="+")

# %%
new_df = df.drop('price',axis='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df,df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[5000]])
# Out:
# array([859554.79452055])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*5000+180616.43835616432
# Out:
# 859554.7945061643

# %% [markdown]
# # Gradiant_Descent

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
def gradient_descent(x,y):
    m_curr = b_curr = 0
    rate = 0.01
    n = len(x)
    plt.scatter(x,y,color='red',marker='+',linewidth='5')
    for i in range(10000):
        y_predicted = m_curr * x + b_curr
        plt.plot(x,y_predicted,color='green')
        md = -(2/n)*sum(x*(y-y_predicted))
        yd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - rate * md
        b_curr = b_curr - rate * yd
        print ("m {}, b {}, iteration {}".format(m_curr,b_curr, i))

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

# %%
gradient_descent(x,y)
# Out:
# m 0.62, b 0.18, iteration 0
# m 1.0928, b 0.3192, iteration 1
# m 1.453232, b 0.42724799999999996, iteration 2
# m 1.7278860800000002, b 0.5115091199999999, iteration 3
# m 1.9370605952000002, b 0.5776057727999999, iteration 4
# m 2.096250917888, b 0.6298300216319999, iteration 5
# m 2.2172859146547204, b 0.6714583661260799, iteration 6
# m 2.309195511463117, b 0.7049920439242751, iteration 7
# m 2.3788729763057748, b 0.7323404723580026, iteration 8
# m 2.431580493177024, b 0.7549612843324961, iteration 9
# m 2.471335107618129, b 0.7739672290552247, iteration 10
# m 2.501203350198827, b 0.7902077780170325, iteration 11
# m 2.523526146474063, b 0.8043314214447622, iteration 12
# m 2.5400905089630834, b 0.8168332242274232, iteration 13
# m 2.55226060353756, b 0.8280911292050898, iteration 14
# m 2.561077803006991, b 0.8383936704087344, iteration 15
# m 2.567337066120929, b 0.8479611288201402, iteration 16
# m 2.5716452438451163, b 0.8569616822764816, iteration 17
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("Desktop/test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
# %matplotlib inline
plt.xlabel('Maths',fontsize="20",color="red")
plt.ylabel('Cs',fontsize="20",color="red")
plt.scatter(df.math,df.cs,color='red',marker="+")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['math']],df.cs)
# Out:
# LinearRegression()

# %%
reg.predict([[30]])
# Out:
# array([32.44730645])

# %%
#gradiant-descent
def maths_cs():
    df = pd.read_csv("Desktop/test_scores.csv")
    reg = linear_model.LinearRegression()
    reg.fit(df[['math']],df.cs)
    return reg.coef_,reg.intercept_

# %%
#m_sklearn, b_sklearn = maths_cs()
#print("Using sklearn: Coef {} Intercept {}".format(m_sklearn,b_sklearn))

# %%
def gradiant(x,y):
    m_cu = b_cu = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.0002
    plt.xlabel('Maths',fontsize="20",color="red")
    plt.ylabel('Cs',fontsize="20",color="red")
    plt.scatter(df.math,df.cs,color='red',marker="+",linewidth="10")
    for i in range(iterations):
        yp = m_cu * x + b_cu #equation of straight line
        mse = (1/n) * sum([val**2 for val in (y-yp)]) #mean square error
        pdm = -(2/n) * sum(x*(y-yp))
        pdb = (2/n) * sum((y-yp))
        m_cu = m_cu - learning_rate * pdm
        b_cu = b_cu - learning_rate * pdb
#        print("m {}, b {}, mse {}, iterations {}".format(m_cu,b_cu,mse,i))
        plt.plot(x,yp,color="blue")
    pass
x = np.array(df.math)
y = np.array(df.cs)

# %%
gradiant(x,y)

# %%
#save model
import joblib
joblib.dump(df,'df_joblib.txt')
# Out:
# ['df_joblib.txt']

# %%
#model = joblib.load('df_joblib.txt')

# %%
#model.coef_

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("Desktop/homeprices.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle.town = le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
x = dfle[['town','area']].values
x
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 4000],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]], dtype=int64)

# %%
y = dfle.price.values
y
# Out:
# array([550000, 565000, 610000, 680000, 725000, 585000, 615000, 650000,
#        710000, 575000, 600000, 620000, 695000], dtype=int64)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('town', OneHotEncoder(), [0])], remainder = 'passthrough')

# %%
x = ct.fit_transform(x)
x
# Out:
# array([[1.0e+00, 0.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.0e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.2e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.6e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 2.9e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.1e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.6e+03]])

# %%
x = x[:,1:]#remove 1st column
x
# Out:
# array([[0.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 3.0e+03],
#        [0.0e+00, 0.0e+00, 3.2e+03],
#        [0.0e+00, 0.0e+00, 3.6e+03],
#        [0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 1.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 2.9e+03],
#        [1.0e+00, 0.0e+00, 3.1e+03],
#        [1.0e+00, 0.0e+00, 3.6e+03]])

# %%
reg = linear_model.LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[0,1,3400]])#west windsor
# Out:
# array([706928.0799828])

# %%
reg.predict([[1,0,2800]])#robinville
# Out:
# array([590775.63964739])

# %%
reg.score(x,y)
# Out:
# 0.9573929037221874

# %% [markdown]
# # Question

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df1 = pd.read_csv("Desktop/carprices.csv")
df1
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
dum = pd.get_dummies(df1['Car Model'])
dum
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
merge = pd.concat([df1,dum], axis="columns")
merge
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6        0       1
# 1                  BMW X5    35000          34000         3        0       1
# 2                  BMW X5    57000          26100         5        0       1
# 3                  BMW X5    22500          40000         2        0       1
# 4                  BMW X5    46000          31500         4        0       1
# 5                 Audi A5    59000          29400         5        1       0
# 6                 Audi A5    52000          32000         5        1       0
# 7                 Audi A5    72000          19300         6        1       0
# 8                 Audi A5    91000          12000         8        1       0
# 9   Mercedez Benz C class    67000          22000         6        0       0
# 10  Mercedez Benz C class    83000          20000         7        0       0
# ...

# %%
final = merge.drop(["Car Model","Mercedez Benz C class"],axis='columns')
final
# Out:
#     Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5
# 0     69000          18000         6        0       1
# 1     35000          34000         3        0       1
# 2     57000          26100         5        0       1
# 3     22500          40000         2        0       1
# 4     46000          31500         4        0       1
# 5     59000          29400         5        1       0
# 6     52000          32000         5        1       0
# 7     72000          19300         6        1       0
# 8     91000          12000         8        1       0
# 9     67000          22000         6        0       0
# 10    83000          20000         7        0       0
# 11    79000          21000         7        0       0
# 12    59000          33000         5        0       0

# %%
x = final.drop("Sell Price($)", axis="columns")

# %%
x
# Out:
#     Mileage  Age(yrs)  Audi A5  BMW X5
# 0     69000         6        0       1
# 1     35000         3        0       1
# 2     57000         5        0       1
# 3     22500         2        0       1
# 4     46000         4        0       1
# 5     59000         5        1       0
# 6     52000         5        1       0
# 7     72000         6        1       0
# 8     91000         8        1       0
# 9     67000         6        0       0
# 10    83000         7        0       0
# 11    79000         7        0       0
# 12    59000         5        0       0

# %%
y = final["Sell Price($)"]
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[45000,4,0,0]])
# Out:
# array([36991.31721061])

# %%
reg.predict([[86000,7,0,1]])
# Out:
# array([11080.74313219])

# %%
reg.score(x,y)
# Out:
# 0.9417050937281083

# %% [markdown]
# # Question with different method

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df2 = pd.read_csv("Desktop/carprices.csv")
df2
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df2["Car Model"] = le.fit_transform(df2["Car Model"])
df2
# Out:
#     Car Model  Mileage  Sell Price($)  Age(yrs)
# 0           1    69000          18000         6
# 1           1    35000          34000         3
# 2           1    57000          26100         5
# 3           1    22500          40000         2
# 4           1    46000          31500         4
# 5           0    59000          29400         5
# 6           0    52000          32000         5
# 7           0    72000          19300         6
# 8           0    91000          12000         8
# 9           2    67000          22000         6
# 10          2    83000          20000         7
# 11          2    79000          21000         7
# 12          2    59000          33000         5

# %%
x = df2[['Car Model','Mileage','Age(yrs)']].values
x
# Out:
# array([[    1, 69000,     6],
#        [    1, 35000,     3],
#        [    1, 57000,     5],
#        [    1, 22500,     2],
#        [    1, 46000,     4],
#        [    0, 59000,     5],
#        [    0, 52000,     5],
#        [    0, 72000,     6],
#        [    0, 91000,     8],
#        [    2, 67000,     6],
#        [    2, 83000,     7],
#        [    2, 79000,     7],
#        [    2, 59000,     5]], dtype=int64)

# %%
y = df2['Sell Price($)'].values
y
# Out:
# array([18000, 34000, 26100, 40000, 31500, 29400, 32000, 19300, 12000,
#        22000, 20000, 21000, 33000], dtype=int64)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([[('town','Mileage', OneHotEncoder(), [0])]], remainder = 'passthrough')

# %%
x = ct.fit_transform(x)
x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-2cd3c7b0b635> in <module>
# ----> 1 x = ct.fit_transform(x)
#       2 x
#
# ~\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     525         # set n_features_in_ attribute
#     526         self._check_n_features(X, reset=True)
# --> 527         self._validate_transformers()
#     528         self._validate_column_callables(X)
#     529         self._validate_remainder(X)
#
# ~\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in _validate_transformers(self)
#     274             return
#     275
# --> 276         names, transformers, _ = zip(*self.transformers)
#     277
#     278         # validate names
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %% [markdown]
# # Training and Testing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df2 = pd.read_csv("Desktop/carprices.csv")
df2
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
df2 = df2.drop('Car Model', axis = "columns")
df2
# Out:
#     Mileage  Sell Price($)  Age(yrs)
# 0     69000          18000         6
# 1     35000          34000         3
# 2     57000          26100         5
# 3     22500          40000         2
# 4     46000          31500         4
# 5     59000          29400         5
# 6     52000          32000         5
# 7     72000          19300         6
# 8     91000          12000         8
# 9     67000          22000         6
# 10    83000          20000         7
# 11    79000          21000         7
# 12    59000          33000         5

# %%
plt.scatter(df2['Age(yrs)'],df2['Sell Price($)'])

# %%
x = df2[['Mileage','Age(yrs)']]
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5

# %%
y = df2['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.3)

# %%
len(x_train)
# Out:
# 9

# %%
len(x_test)
# Out:
# 4

# %%
len(y_train)
# Out:
# 9

# %%
len(y_test)
# Out:
# 4

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 6     52000         5
# 9     67000         6
# 5     59000         5
# 2     57000         5
# 0     69000         6
# 11    79000         7
# 4     46000         4
# 10    83000         7
# 12    59000         5

# %%
x_test
# Out:
#    Mileage  Age(yrs)
# 3    22500         2
# 8    91000         8
# 7    72000         6
# 1    35000         3

# %%
y_train
# Out:
# 6     32000
# 9     22000
# 5     29400
# 2     26100
# 0     18000
# 11    21000
# 4     31500
# 10    20000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 3    40000
# 8    12000
# 7    19300
# 1    34000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.9145000493373069

# %%
x_test
# Out:
#    Mileage  Age(yrs)
# 3    22500         2
# 8    91000         8
# 7    72000         6
# 1    35000         3

# %%
reg.predict(x_test)
# Out:
# array([42591.89877209, 14495.95687332, 23277.7178796 , 37744.3246481 ])

# %%
y_test
# Out:
# 3    40000
# 8    12000
# 7    19300
# 1    34000
# Name: Sell Price($), dtype: int64

# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df3 = pd.read_csv("Desktop/insurance_data.csv")
df3
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df3.age,df3.bought_insurance,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df3[['age']],df3.bought_insurance,test_size=0.2)

# %%
X_test
# Out:
#     age
# 6    55
# 3    52
# 23   45
# 21   26
# 15   55
# 19   18

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 6    55
# 3    52
# 23   45
# 21   26
# 15   55
# 19   18

# %%
y_predicted = reg.predict(X_test)

# %%
reg.predict_proba(X_test)
# Out:
# array([[8.44914710e-04, 9.99155085e-01],
#        [2.11149898e-03, 9.97888501e-01],
#        [1.76685530e-02, 9.82331447e-01],
#        [8.57013485e-01, 1.42986515e-01],
#        [8.44914710e-04, 9.99155085e-01],
#        [9.85748416e-01, 1.42515840e-02]])

# %%
y_predicted
# Out:
# array([1, 1, 1, 0, 1, 0], dtype=int64)

# %% [markdown]
# # Questions

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df4 = pd.read_csv("Desktop/HR_comma_sep.csv")
df4
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
left = df4[df4.left==1]
left.shape
# Out:
# (3571, 10)

# %%
retained = df4[df4.left==0]
retained.shape
# Out:
# (11428, 10)

# %%
df4.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
pd.crosstab(df4.salary,df4.left).plot(kind='bar')

# %%
pd.crosstab(df4.Department,df4.left).plot(kind='bar')

# %%
subdf = df4[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %%
salary_dummies = pd.get_dummies(subdf.salary, prefix="salary")

# %%
df_with_dummies = pd.concat([subdf,salary_dummies],axis='columns')

# %%
df_with_dummies.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
x = df_with_dummies.drop('salary',axis='columns')
x
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
y = df4.left

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\JMD\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 0.7751111111111111
